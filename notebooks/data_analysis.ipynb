# %% [markdown]
# # Data Analysis notebook for highly sophisticated analysis

# %%
# dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ## Data import

# %%
# load data
path = Path('C:/Users/janni/Desktop/blueprint/ml-blueprint-arch')
df = pd.read_pickle(path / 'data' / 'dat.pkl')

# %% [markdown]
# ## EDA

# %%
df.describe()
# Out:
#                  y           x1           x2
# count  1000.000000  1000.000000  1000.000000
# mean     39.788377     9.880232    29.925313
# std       5.702478     2.877796     4.858526
# min      18.403126     1.435206    10.631365
# 25%      35.922434     7.933542    26.581331
# 50%      39.677014     9.907517    29.932834
# 75%      43.731537    11.929501    33.253557
# max      58.063512    18.460038    46.429890

# %%
df['y'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Oh wow, what a surprise, it appears normally distributed. Who could have guessed?

# %%
df['x1'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Same here?!

# %%
df['x2'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# And same here, too?!

# %% [markdown]
# Let's check if our variables are actually correlated.

# %%
df.corr()
# Out:
#           y        x1        x2
# y   1.00000  0.474780  0.853420
# x1  0.47478  1.000000 -0.021289
# x2  0.85342 -0.021289  1.000000

# %% [markdown]
# Oh wow, they are! This analysis is spot-on!

# %%
df.plot.scatter(x='x1', y='x2')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
df.plot.scatter(x='x1', y='y')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='y'>

# %%
df.plot.scatter(x='x2', y='y')
# Out:
# <AxesSubplot:xlabel='x2', ylabel='y'>

# %% [markdown]
# #### Obvious linear correlations, no (linear) correlation between our dependent variables. Let's go for a linear regression model, then?
